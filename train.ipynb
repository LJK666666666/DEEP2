# %%
# !cd SSD-Resnet-Attention-FeatureFusion-master && python train.py --config-file configs/vgg_ssd512_voc0712.yaml
# Out:
# 2025-12-09 23:55:56,532 SSD INFO: Using 1 GPUs
# 2025-12-09 23:55:56,532 SSD INFO: Namespace(config_file='configs/vgg_ssd512_voc0712.yaml', local_rank=0, log_step=10, save_step=20000, eval_step=2000, use_tensorboard=False, early_stop_patience=10, early_stop_min_delta=0.0005, skip_test=False, opts=[], distributed=False, num_gpus=1)
# 2025-12-09 23:55:56,535 SSD INFO: Loaded configuration file configs/vgg_ssd512_voc0712.yaml
# 2025-12-09 23:55:56,536 SSD INFO:
# MODEL:
#   NUM_CLASSES: 21
#   BACKBONE:
#     OUT_CHANNELS: (512, 1024, 512, 256, 256, 256, 256)
#   PRIORS:
#     FEATURE_MAPS: [64, 32, 16, 8, 4, 2, 1]
#     STRIDES: [8, 16, 32, 64, 128, 256, 512]
#     MIN_SIZES: [35.84, 76.8, 153.6, 230.4, 307.2, 384.0, 460.8]
#     MAX_SIZES: [76.8, 153.6, 230.4, 307.2, 384.0, 460.8, 537.65]
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 6, 4, 4]
# INPUT:
#   IMAGE_SIZE: 512
# DATASETS:
#   TRAIN: ("voc_2007_trainval",)
# ...

# %% [markdown]
# 100 23:56:38
# 2100 00:05:15
# 10100 00:37:43

# %%
# !cd SSD-Resnet-Attention-FeatureFusion-master && python train.py --config-file configs/vgg_ssd512_voc0712_cosine.yaml --init_weight outputs/vgg_ssd512_voc0712.pth

# %%
# !cd SSD-Resnet-Attention-FeatureFusion-master && python train.py --config-file configs/vgg_ssd512_voc0712_plateau.yaml --init_weight outputs/vgg_ssd512_voc0712.pth

# %%
# !cd SSD-Resnet-Attention-FeatureFusion-master && python test.py --config-file configs/vgg_ssd512_voc0712.yaml --ckpt outputs/vgg_ssd512_voc0712.pth
# Out:
# 2025-12-12 01:30:25,396 SSD INFO: Using 1 GPUs
# 2025-12-12 01:30:25,397 SSD INFO: Namespace(config_file='configs/vgg_ssd512_voc0712.yaml', local_rank=0, ckpt='outputs/vgg_ssd512_voc0712.pth', output_dir='eval_results', opts=[])
# 2025-12-12 01:30:25,397 SSD INFO: Loaded configuration file configs/vgg_ssd512_voc0712.yaml
# 2025-12-12 01:30:25,399 SSD INFO:
# MODEL:
#   NUM_CLASSES: 21
#   BACKBONE:
#     OUT_CHANNELS: (512, 1024, 512, 256, 256, 256, 256)
#   PRIORS:
#     FEATURE_MAPS: [64, 32, 16, 8, 4, 2, 1]
#     STRIDES: [8, 16, 32, 64, 128, 256, 512]
#     MIN_SIZES: [35.84, 76.8, 153.6, 230.4, 307.2, 384.0, 460.8]
#     MAX_SIZES: [76.8, 153.6, 230.4, 307.2, 384.0, 460.8, 537.65]
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 6, 4, 4]
# INPUT:
#   IMAGE_SIZE: 512
# DATASETS:
#   TRAIN: ("voc_2007_trainval", "voc_2007_test", )
#   TEST: ("voc_2012_trainval", )
# SOLVER:
#   MAX_ITER: 120000
# ...

# %%
# !cd SSD-Resnet-Attention-FeatureFusion-master && python test.py --config-file configs/vgg_ssd512_voc0712.yaml --ckpt outputs/vgg_ssd512_voc0712.pth
# Out:
# 2025-12-12 01:34:18,404 SSD INFO: Using 1 GPUs
# 2025-12-12 01:34:18,404 SSD INFO: Namespace(config_file='configs/vgg_ssd512_voc0712.yaml', local_rank=0, ckpt='outputs/vgg_ssd512_voc0712.pth', output_dir='eval_results', opts=[])
# 2025-12-12 01:34:18,404 SSD INFO: Loaded configuration file configs/vgg_ssd512_voc0712.yaml
# 2025-12-12 01:34:18,408 SSD INFO:
# MODEL:
#   NUM_CLASSES: 21
#   BACKBONE:
#     OUT_CHANNELS: (512, 1024, 512, 256, 256, 256, 256)
#   PRIORS:
#     FEATURE_MAPS: [64, 32, 16, 8, 4, 2, 1]
#     STRIDES: [8, 16, 32, 64, 128, 256, 512]
#     MIN_SIZES: [35.84, 76.8, 153.6, 230.4, 307.2, 384.0, 460.8]
#     MAX_SIZES: [76.8, 153.6, 230.4, 307.2, 384.0, 460.8, 537.65]
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 6, 4, 4]
# INPUT:
#   IMAGE_SIZE: 512
# DATASETS:
#   TRAIN: ("voc_2007_trainval", "voc_2007_test", )
#   # TEST: ("voc_2012_trainval", )
#   TEST: ("voc_2007_test", )
# SOLVER:
# ...

# %%
# !cd SSD-Resnet-Attention-FeatureFusion-master && python test.py --config-file configs/vgg_ssd512_voc0712.yaml --ckpt outputs/vgg_ssd512_voc0712.pth
# Out:
# 2025-12-12 01:35:51,518 SSD INFO: Using 1 GPUs
# 2025-12-12 01:35:51,518 SSD INFO: Namespace(config_file='configs/vgg_ssd512_voc0712.yaml', local_rank=0, ckpt='outputs/vgg_ssd512_voc0712.pth', output_dir='eval_results', opts=[])
# 2025-12-12 01:35:51,518 SSD INFO: Loaded configuration file configs/vgg_ssd512_voc0712.yaml
# 2025-12-12 01:35:51,519 SSD INFO:
# MODEL:
#   NUM_CLASSES: 21
#   BACKBONE:
#     OUT_CHANNELS: (512, 1024, 512, 256, 256, 256, 256)
#   PRIORS:
#     FEATURE_MAPS: [64, 32, 16, 8, 4, 2, 1]
#     STRIDES: [8, 16, 32, 64, 128, 256, 512]
#     MIN_SIZES: [35.84, 76.8, 153.6, 230.4, 307.2, 384.0, 460.8]
#     MAX_SIZES: [76.8, 153.6, 230.4, 307.2, 384.0, 460.8, 537.65]
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 6, 4, 4]
# INPUT:
#   IMAGE_SIZE: 512
# DATASETS:
#   TRAIN: ("voc_2007_trainval", "voc_2007_test", )
#   # TEST: ("voc_2012_trainval", )
#   TEST: ("voc_2007_trainval", )
# SOLVER:
# ...

# %% [markdown]
# test 2767mb
